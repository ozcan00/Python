# %% [markdown]
# #  4. KOŞULLU DURUMLAR
#
# ### Bu bölümde;
# - Program yazma sürecinde kullanılan koşullu durumlar konusunda bilgi sahibi olacak,
# - İç içe koşul durumu ifade etmeyi kavrayacak,
# - Koşul durumlarında yapılan hatalar konusunda fikir sahibi olacaksınız.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.1. Boolean İfadesi
# ```python
# Bilgisayar bilimi temelde 0 ve 1 değerleri üzerine kurulmuştur;
# 0 değeri False(Yanlış), 1 değeri True(Doğru) demektir. Bu ifadelere Boolean (bool) İfadeleri denir.
# Doğru ve Yanlış değerleri korumak için kullanılan tipe bool adı verilmektedir. Sadece iki Boolean ifade değeri vardır:
# '• True == (Doğru) (1) '
# '• False == (Yanlış) (0)'
# ```

# %% [markdown]
# ## 4.2. Python’da İlişkisel Operatörler
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 4.3. “if” İfadesi
# ```python
# Türkçede 'EĞER' anlamına gelen if ifadesi, adından da anlaşılacağı üzere bir koşula bağlı durumları kontrol etmek amacıyla kullanılır
# ```
#
# ![image.png](attachment:image.png)

# %%
if True and True:
    print("Mantık Doğru")
else:
    print("Mantık Yanlış")

if True or False:
    print("Mantık Doğru")
else:
    print("Mantık Yanlış")
# Out:
# Mantık Doğru
# Mantık Doğru

# %% [markdown]
# ### 4.4. “if/else” İfadesi
# ```python
# “if/else” ifadesi, “if” ifadesi ile birlikte çalışır ve if koşullarının sağlanmadığı tüm durumları kapsar
# ```
# ![image.png](attachment:image.png)

# %%
# Örnek If Koşul Durumu
sayi = 72
if sayi > (sayi-1):
    print(True)
else:
    print(False)


# Bölme İşlemi 

print("Lütfen bölme işlemi için iki sayı giriniz!")
bolunen = int(input("Lütfen bölünen sayıyı giriniz: "))
bolen = int(input("Lütfen bölen sayıyı giriniz: "))

if bolen !=0:   # bolen 0'ra eşit değilse                                     
    print(bolunen, "/", bolen, "=", bolunen/bolen)      
else:
    print("Sıfıra bölme işlemi yapılamaz!!!!")  # if bolen == 0: ---> Division zero error
# Out:
# True
# Lütfen bölme işlemi için iki sayı giriniz!
# Sıfıra bölme işlemi yapılamaz!!!!

# %% [markdown]
# ### 4.5. Birleşik Boolean İfadesi
# ```python
# Boolean ifadesi ile bir ilişkisel operatörle birleştirilerek daha karmaşık Boolean ifadeleri oluşturabilir.
# Bu tür durumlarda 3 farklı mantıksal operatörden yararlanılabilir: and, or ve not. Mantıksal operatörler
# aracılığı ile iki veya daha fazla Boolean ifadesinin kullanıldığı deyimlere Birleşik Boolean İfadeleri denir.
# ```

# %%
# Sayı Karşılaştırma Örneği

sayi1 = 20
sayi2 = 10  
sayi3 = -10
 
if sayi1 > 0 and sayi2 > 0:
    print("Birinci ve ikinci sayılar 0'dan büyüktür ")

if sayi1 > 0 and sayi2 > 0 and sayi3 > 0:
    print("Tüm sayılar 0'dan büyüktür")

if sayi1 > sayi2 and sayi2 > sayi3:
    print("En büyük sayı: ", sayi1)
if sayi3 < 0:
    print("Negatif olan sayı: ", sayi3)

else:
    print("En az bir sayı 0'dan büyük değil")

# The Champions Leauge Team Winner Cups | Kodlar üzerinde değişiklik yaparak diğer takımları karşılaştırın..

RealMardin = 19874512584415668337137931860  
Barcelona = 5128458
RealMadrid = 132
Galatasaray = 4
Fenerbahce = 2.5
Besiktas = 3
Gungorenspor = 0
Bagcilar = -1

if Barcelona > RealMadrid and Barcelona < RealMardin:
    print("En büyük Şampiyon Mardin", "ve kupa sayısı = ", RealMardin)

if Gungorenspor < RealMardin:
    print("En büyük Şampiyon Mardin", "ve kupa sayısı = ", RealMardin)
# Out:
# Birinci ve ikinci sayılar 0'dan büyüktür
# En büyük sayı:  20
# Negatif olan sayı:  -10
# En büyük Şampiyon Mardin ve kupa sayısı =  19874512584415668337137931860
# En büyük Şampiyon Mardin ve kupa sayısı =  19874512584415668337137931860

# %% [markdown]
# ## 4.6. Pass İfadesi
# ```python
# pass ifadesi Python’da herhangi bir işlem yapmadan geçeceğimiz durumlarda kullanılır. Kısaca
# “Hiçbir şey yapmadan yola devam et!” anlamı katar.
# ```

# %%
x = 4
if x == 2:
    print(x)
else:
    pass           # eğer x 2’ye eşit ise x yazdır eşit değilse hiçbir şey yapma geç
if x != 2:
    print(x +1)    # eğer x 2'ye eşit değilse x'e 1 ekleyerek yazdır
# Out:
# 5

# %% [markdown]
# ## 4.7. Kayan Noktalı Eşitlik
# Eşitlik operatörü (==) gerçek eşitlik olup olmadığını kontrol eder.
# Ancak kayan noktalı sayılarla işlem yaparken bu durum sorun oluşturabilir.

# %%
islem1 = (1.11 - 1.10)
islem2= (2.11 - 2.10)

print("Birinci İşlem =", islem1, " İkinci İşlem =", islem2)

if islem1 == islem2:
    print("Sonuç Aynı")

else:
    print("Sonuç Farklı")
# Out:
# Birinci İşlem = 0.010000000000000009  İkinci İşlem = 0.009999999999999787
# Sonuç Farklı

# %% [markdown]
# ## 4.8. İç İçe Koşul İfadeleri
# Karşılaştırma yapıları kullanırken bazı durumlarda istenilen koşulların birden fazla şarta aynı anda
# uyması istenebilir. Bu durumda koşul yapılarının birbirinin içinde kullanılması gerekir. Bu şekilde bir
# yapı kullanıldığında istenilen komut veya komut kümelerinin yapılması için iki koşul ifadesinin de True
# olması gerekir

# %%
Rakam = int(input("Lütfen 0 yada 5 tam sayı değerlerinden birini girin: "))

if Rakam < 0:
   print("Girilen Sayı Sıfırdan Küçüktür!", Rakam)
else:
    if Rakam == 0:
        print("Girilen Sayı Sıfırdır!", Rakam)
    else:
        if Rakam == 1:
            print("Girilen Sayı Birdir", Rakam)
        else:
            if Rakam == 5:
                print("Girilen Sayı Beştir", Rakam)
            else:
                print("Girilen Sayı Çok Büyüktür!", Rakam)
                
print("Tamamlandı")
# Out:
# Girilen Sayı Sıfırdır! 0
# Tamamlandı

# %% [markdown]
# ## 4.9. Çok Yönlü Karar İfadeleri
# ```python
# Basit if/else ifadesinde iki farklı koşul varken çok yönlü karar ifadelerinde daha fazla koşulun gerçekleşme durumuna göre işlem yapılır. Bunun için kod yazılırken iç içe if/else ifadeleri gerekir
# ```
# ```python
# Python’da çok yönlü koşullu durumlar iç içe if ifadeleri yanında if/elif/else ifadesi ile birlikte de kullanılabilir. Elif ifadesi, else if ifadesinin kısaltmasıdır. Örneğin,
# ```

# %%
sys_kullanici = "admin"
sys_sifre = "demo"
yas = 20

kullanici = input("Kullanıcı adı: ")
sifre = (input("Kullanıcı adı: "))

if sys_kullanici == kullanici and sys_sifre == sifre and yas >= 20:
    print("Sisteme Giriş Başarılı")
    if len(sifre) < 6:
        print("Sifreniz daha uzun olmalı!")

else:  
    print("Bilgilerini kontrole edin!")
# Out:
# Sisteme Giriş Başarılı
# Sifreniz daha uzun olmalı!

# %% [markdown]
# ## 4.10. Çok Yönlü ve Zincirleme Durum İfadeleri
#
# İkiden fazla olasılığın olduğu durumlarda ikiden fazla dallanmaya (yol) gereksinim duyarız. Bu tür
# durumlarda zincirleme koşul ifadeleri kullanılır. Her koşul sırasıyla sınanır.
# İlki yanlış ise sonraki kontrol edilir ve yazılan kodun tamamı bu şekilde çalıştırılır.
# Koşullardan biri doğru ise ilgili dal yürütülür ve cümlenin işlevi biter.
# Eğer birden fazla koşul doğru ise sadece ilk karşılaşılan doğru dal çalışır.
#
# ![image.png](attachment:image.png)
#
# Yukarıdaki problemde kullanıcının klavyeden “1” girmesi durumunda işletilecek şartlar belirtilmiştir.
# Çok Yönlü Koşullu Durum yapısında Kontrol 1 kısmına girilecek fakat şart sağlanmadığı için
# sonuç kısmına girilmeyecek ve Kontrol 2 kısmına girilecektir. Geçilen bu aşamada şart sağlandığı için
# print() komutu işletilecek ve diğer tüm kontrol satırları atlanacaktır. Böylece fazla koşul kontrollerinden
# kaçınılmış olacaktır. Ancak Zincirleme Durum ifadesinde tüm şartlar sırasıyla kontrol edilecek, şartı
# sağlayanlar için print() satırları yapılacaktır.

# %% [markdown]
# ## 4.11. Koşullu İfadeler
# Koşullu ifadelerin genel yapısı aşağıdaki gibidir.
#
# ![image.png](attachment:image.png)

# %%
'Birinci Durum if Koşul else İkinci Durum'

n = int(input("Bir sayı giriniz: "))
print("|", n, "| = ", (-n if n < 0 else n), sep="")
# Out:
# |-125| = 125

# %% [markdown]
# ## 4.11.1. Koşullu İfadelerde Hatalar
# ```python
# deger = int(input("Lütfen 0 – 5 arasında bir değer girin: "))
# cevap="aralıkta değil" #Varsayılan Cevap [Yani 0 - 5 aralığıd olmayan bir sayı girilirse belirtilen koşulun dışında kalır ]
# ```

# %% [markdown]
# ## 4.12. Mantık Karmaşası
# ```python
# Python, çok karmaşık durum/koşul ifadelerini oluşturmak için gerekli araçları sağlar. Ancak önemli
# olan, mantık karmaşasına yol açmadan kullanabilmektir. Boolean ifadeleri and ve not ile birlikte kullanılmak istendiğinde, karmaşık mantığa dayalı koşullar oluşturmamıza olanak sağlar.
#
# Örneğin aşağıdaverilen 4 farklı  Bollean ifade kodu çalıştırıldığı zaman aynı sonucu verecektir.
#
# 1. not (a == b and c != d)
# 2. not (a == b and not (c == d))
# 3. not (a == b) or not (c != d)
# 4. (a != b) or (c == d)
#
# Ancak unutulmamalıdır ki;
# • Çalıştırılırken en verimli yöntem basit düzeydeki mantıksal ifadelerdir.
# • Basit düzeydeki mantıksal ifadeleri yazmak ve çalıştırmak daha kolaydır.
# • Basit düzeydeki mantıksal ifadeler, çalıştırılırken de en verimli yöntemdir.
# • Basit düzeydeki mantıksal ifadelerin değiştirilmesi, düzenlenmesi ve genişletilmesi de daha kolaydır.
# ```

# %% [markdown]
# - Kaynakça ve İleri Okuma:
#
# `Python Resmi Sitesi` ----> https://www.python.org/
#
# `w3schools` ------------------> https://www.w3schools.com/python/default.asp
#
# `Yazbel Forumu!`  -----------> https://yazbel.com/

# %% [markdown]
# #### `Mehmet Özcan` | Bilişim Teknolojileri Öğretmeni
#
# `Hakkımda daha fazla bilgiye` https://my.indeed.com/p/mehmetz-3kxtvpl adresinden ulaşabilirsiniz
